# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
hygiene_count = establishments.count_documents(query)
# Display the first document in the results using pprint
pprint(hygiene_count)
# Out:
# 41

# %%
results = establishments.find(query)
# Convert the result to a Pandas DataFrame
hygiene_count_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(hygiene_count_df.shape[0])
# Display the first 10 rows of the DataFrame
hygiene_count_df.head(10)
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  66737eaed4ffeb82dd95b751   110681                  0
# 1  66737eaed4ffeb82dd95bad1   612039                  0
# 2  66737eaed4ffeb82dd95bdda   730933                  0
# 3  66737eaed4ffeb82dd95bfc8   172735                  0
# 4  66737eaed4ffeb82dd95bfd8   172953                  0
# 5  66737eaed4ffeb82dd95c976   512854                  0
# 6  66737eaed4ffeb82dd95cb9a  1537089                  0
# 7  66737eafd4ffeb82dd95e0c3   155648                  0
# 8  66737eafd4ffeb82dd95e506  1012883                  0
# 9  66737eafd4ffeb82dd95ed18   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    'AddressLine4': 'London',
    'RatingValue': {'$gte': 4}
}

# Use count_documents to display the number of documents in the result
rv_count = establishments.count_documents(query)
print(rv_count)
# Display the first document in the results using pprint
results = establishments.find(query)

for i in range(1):
    pprint(results[i])
# Out:
# 390
# {'AddressLine1': 'Arch D',
#  'AddressLine2': 'The Link Thamesmead',
#  'AddressLine3': 'Bazalgette Way',
#  'AddressLine4': 'London',
#  'BusinessName': 'The Mezzanine Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4646.357884390823,
#  'FHRSID': 1049722,
#  'LocalAuthorityBusinessID': '18/00096/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE2 9BS',
#  'RatingDate': '2022-05-24T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66737eafd4ffeb82dd960c03'),
#  'geocode': {'latitude': 51.5002632141113, 'longitude': 0.121751002967358},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1049722',
# ...

# %%
# Convert the result to a Pandas DataFrame
london_rating_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(london_rating_df.shape[0])
# Display the first 10 rows of the DataFrame
london_rating_df.head(10)
# Out:
# 390
#                         _id   FHRSID  ChangesByServerID  \
# 0  66737eafd4ffeb82dd960c03  1049722                  0
# 1  66737eafd4ffeb82dd960c23  1261451                  0
# 2  66737eafd4ffeb82dd960c28   357627                  0
# 3  66737eafd4ffeb82dd960c29   987733                  0
# 4  66737eafd4ffeb82dd960c46  1151706                  0
# 5  66737eafd4ffeb82dd960c48  1468037                  0
# 6  66737eafd4ffeb82dd960c4b   358232                  0
# 7  66737eafd4ffeb82dd960c54  1415217                  0
# 8  66737eafd4ffeb82dd960c68   357579                  0
# 9  66737eafd4ffeb82dd960c69   635108                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0              18/00096/CP                                 The Mezzanine Cafe
# 1           20/00255/MIXED  St Edward's Church, Mottingham - StEP Lunch Cl...
# 2         00000/0000/8/951                                              Co-op
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
penang = establishments.find_one({'BusinessName': 'Penang Flavours'})
pprint(penang)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6673870c6f776a8fe1e29032'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.490142
longitude = 0.08384

query = {
    '$and': [
        {'RatingValue': 5},
        {
            '$or': [
                {'geocode.latitude': {'$lte': 51.500142}},
                {'geocode.longitude': {'$lte': 0.09384}},
                {'geocode.latitude': {'$gte': 51.480142}},
                {'geocode.longitude': {'$lte': 0.07384}}
            ]
        }
    ]
}
sort = {'scores.Hygiene': 1}

count = establishments.count_documents(query)
print(count)
# Print the results
results = establishments.find(query).sort(sort)
results_list = list(results)

# Print the results
for result in results_list[:5]:
    pprint(result)
# Out:
# 25816
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Little Rock',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1423242,
#  'LocalAuthorityBusinessID': 'PI/000078141',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66737eaed4ffeb82dd959c2c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
# ...

# %%
# Convert result to Pandas DataFrame
penang_df = pd.DataFrame(results_list)
penang_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25816 entries, 0 to 25815
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         25816 non-null  object
#  1   FHRSID                      25816 non-null  int64
#  2   ChangesByServerID           25816 non-null  int64
#  3   LocalAuthorityBusinessID    25816 non-null  object
#  4   BusinessName                25816 non-null  object
#  5   BusinessType                25816 non-null  object
#  6   BusinessTypeID              25816 non-null  int64
#  7   AddressLine1                25816 non-null  object
#  8   AddressLine2                25816 non-null  object
#  9   AddressLine3                25816 non-null  object
#  10  AddressLine4                25816 non-null  object
#  11  PostCode                    25816 non-null  object
#  12  Phone                       25816 non-null  object
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query = {'$match': {'scores.Hygiene': 0}}
group_query = {'$group': {'_id': "$LocalAuthorityName", 'count': {'$sum': 1}}}
sort_values = {'$sort': { 'count': -1, '_id': 1 }}
# Print the number of documents in the result
pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(len(results))
# Print the first 10 results
pprint(results[0:10])
# Out:
# 55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
penang_hygiene_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(penang_hygiene_df.shape[0])
# Display the first 10 rows of the DataFrame
penang_hygiene_df.head(10)
# Out:
# 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
